# %% [markdown]
# # Dataset de supermercado para regras de associação
#
# O conjunto de dados de comportamento do consumidor de supermercado consiste em 2.019.501 linhas e 12 colunas:
# * **order_id** (Um número exclusivo para identificar o pedido)
# * **user_id** - (Um número exclusivo para identificar o usuário)
# * **order_number** (Número do pedido)
# * **order_dow** (Dia da semana em que o pedido foi feito)
# * **order_hour_of_day** (Hora do pedido)
# * **dias_since_prior_order** (Histórico do pedido)
# * **product_id** (Id do produto)
# * **add_to_cart_order** (Número de itens adicionados ao carrinho)
# * **reordenado** (se o novo pedido ocorreu)
# * **departamental_id** (Número exclusivo alocado para cada departamento)
# * **departament** (Nomes dos departamentos)
# * **product_name** (Nome dos produtos)
#
# **Fonte dos dados:**
# O conjunto de dados consiste em mais de 2 milhões de registros de compras em um renomado supermercado Hunter :)
#
# https://www.kaggle.com/datasets/hunter0007/ecommerce-dataset-for-predictive-marketing-2023/data
#
# ## Explicação do algorítimo Apriori
# Suponha que temos a regra de associação
# {Pão} →{Manteiga} com um suporte de **0.1**, uma confiança de **0.6** e um lift de **1.5**.
#
# **Suporte** (Pão): 10% das transações contêm pão.
#
# **Confiança** (Pão → Manteiga): 60% das transações que contêm pão também contêm manteiga.
#
# **Lift** (Pão → Manteiga): A probabilidade de comprar pão e manteiga juntos é 1.5 vezes maior do que se fossem comprados independentemente.
#
# Portanto, ao comprar pão, há uma probabilidade de 60% de que manteiga também seja comprada, e essa probabilidade é 1.5 vezes maior do que se pão e manteiga fossem comprados independentemente. Isso ajuda a identificar associações interessantes nos dados de transações.

# %%
#instalar a biblioteca apyori
#!pip install apyori

# %%
import pandas as pd
from apyori import apriori

# %%
#carga de dados
dados = pd.read_csv('ECommerce_consumer behaviour.csv')
dados.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2425083    49125             1          2                 18
# 1   2425083    49125             1          2                 18
# 2   2425083    49125             1          2                 18
# 3   2425083    49125             1          2                 18
# 4   2425083    49125             1          2                 18
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN          17                  1          0
# 1                     NaN          91                  2          0
# 2                     NaN          36                  3          0
# 3                     NaN          83                  4          0
# 4                     NaN          83                  5          0
#
#    department_id  department        product_name
# 0             13      pantry  baking ingredients
# 1             16  dairy eggs     soy lactosefree
# 2             16  dairy eggs              butter
# 3              4     produce    fresh vegetables
# 4              4     produce    fresh vegetables

# %% [markdown]
# Para esse projeto, iremos utilizar apenas as colunas **order_id** e **product_name**

# %%
#manter somente order_id e product_name
dados = dados[['order_id', 'product_name']]
dados.head()
# Out:
#    order_id        product_name
# 0   2425083  baking ingredients
# 1   2425083     soy lactosefree
# 2   2425083              butter
# 3   2425083    fresh vegetables
# 4   2425083    fresh vegetables

# %%
#shape do dataset
dados.shape
# Out:
# (2019501, 2)

# %%
#remove linhas com produtos 'missing'
dados = dados[dados['product_name'] != 'missing']

# %%
#descreve a quantidade de produtos
count_prod = dados.product_name.value_counts()
count_prod.describe()
# Out:
# count       133.000000
# mean      15148.511278
# std       30059.403362
# min         279.000000
# 25%        2020.000000
# 50%        6321.000000
# 75%       17408.000000
# max      226039.000000
# Name: product_name, dtype: float64

# %%
#separar apenas uma amostra de dados (dataset muito grande)
dados_amostra = dados[:20000]

# %%
#media de produtos por transação
dados_amostra.groupby('order_id').count().mean()
# Out:
# product_name    9.985022
# dtype: float64

# %%
#agrupar por order_id, e criar uma lista de produtos para cada ordem.

ordem_prod_agrupados = dados_amostra.groupby('order_id')['product_name'].apply(list).reset_index().drop(columns=['order_id'])
ordem_prod_agrupados = ordem_prod_agrupados['product_name'].values

ordem_prod_agrupados
# Out:
# array([list(['frozen meals', 'fresh dips tapenades', 'canned meals beans', 'chips pretzels', 'oils vinegars']),
#        list(['pasta sauce', 'water seltzer sparkling water', 'chips pretzels', 'frozen produce', 'water seltzer sparkling water', 'fresh fruits']),
#        list(['other creams cheeses', 'refrigerated', 'soup broth bouillon', 'yogurt', 'yogurt']),
#        ..., list(['packaged cheese', 'pasta sauce']),
#        list(['prepared soups salads', 'prepared soups salads', 'prepared soups salads']),
#        list(['coffee', 'coffee', 'water seltzer sparkling water', 'fresh herbs', 'yogurt', 'dry pasta', 'packaged vegetables fruits', 'milk', 'water seltzer sparkling water', 'pasta sauce', 'asian foods', 'fresh herbs', 'eggs'])],
#       dtype=object)

# %%
#para cada transação, considerar apenas os 20 primeiros itens, sendo que nas transações
# (somente quando houver muitos produtos no carrinho, mas não é obrigatório)

transactions = []

for x in range(len(ordem_prod_agrupados)):
    linha = ordem_prod_agrupados[x][:20]
    transactions.append(linha)
transactions
# Out:
# [['frozen meals',
#   'fresh dips tapenades',
#   'canned meals beans',
#   'chips pretzels',
#   'oils vinegars'],
#  ['pasta sauce',
#   'water seltzer sparkling water',
#   'chips pretzels',
#   'frozen produce',
#   'water seltzer sparkling water',
#   'fresh fruits'],
#  ['other creams cheeses',
#   'refrigerated',
#   'soup broth bouillon',
#   'yogurt',
#   'yogurt'],
#  ['water seltzer sparkling water',
#   'refrigerated',
#   'refrigerated',
#   'coffee',
#   'yogurt',
#   'tea'],
#  ['butter',
#   'chips pretzels',
#   'breakfast bakery',
#   'food storage',
#   'fresh dips tapenades',
#   'trail mix snack mix',
#   'soft drinks',
#   'crackers'],
#  ['cream',
#   'milk',
#   'milk',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'packaged cheese',
#   'packaged cheese',
#   'cereal',
#   'fresh fruits',
#   'fresh vegetables',
#   'spreads',
#   'fresh fruits'],
#  ['ice cream ice', 'fresh dips tapenades', 'fresh fruits'],
#  ['frozen appetizers sides',
#   'crackers',
#   'spreads',
#   'popcorn jerky',
#   'lunch meat',
#   'soup broth bouillon',
#   'fresh fruits',
#   'crackers',
#   'juice nectars'],
#  ['water seltzer sparkling water',
#   'eggs',
#   'frozen produce',
#   'refrigerated',
#   'eggs',
#   'fresh vegetables',
#   'canned jarred vegetables',
#   'preserved dips spreads',
#   'baking ingredients',
#   'frozen produce',
#   'packaged vegetables fruits',
#   'oils vinegars',
#   'nuts seeds dried fruit'],
#  ['cereal',
#   'canned jarred vegetables',
#   'canned meals beans',
#   'fresh herbs',
#   'fresh vegetables',
#   'fresh fruits',
#   'canned fruit applesauce',
#   'baby food formula',
#   'milk',
#   'water seltzer sparkling water',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh vegetables'],
#  ['fresh vegetables',
#   'eggs',
#   'canned meals beans',
#   'fresh fruits',
#   'tortillas flat bread',
#   'packaged vegetables fruits',
#   'fresh herbs',
#   'fresh vegetables',
#   'packaged cheese',
#   'fresh vegetables'],
#  ['coffee',
#   'fresh fruits',
#   'milk',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'fresh dips tapenades',
#   'fresh fruits',
#   'fresh fruits'],
#  ['refrigerated',
#   'yogurt',
#   'yogurt',
#   'yogurt',
#   'yogurt',
#   'nuts seeds dried fruit',
#   'fresh vegetables',
#   'instant foods',
#   'pickled goods olives',
#   'cream',
#   'nuts seeds dried fruit',
#   'nuts seeds dried fruit',
#   'nuts seeds dried fruit',
#   'coffee'],
#  ['cookies cakes',
#   'cream',
#   'soy lactosefree',
#   'doughs gelatins bake mixes',
#   'tofu meat alternatives',
#   'packaged cheese',
#   'coffee',
#   'milk',
#   'chips pretzels'],
#  ['feminine care',
#   'soap',
#   'chips pretzels',
#   'soft drinks',
#   'water seltzer sparkling water',
#   'water seltzer sparkling water',
#   'water seltzer sparkling water',
#   'juice nectars'],
#  ['bread',
#   'dry pasta',
#   'pasta sauce',
#   'milk',
#   'spreads',
#   'fresh vegetables',
#   'fresh vegetables',
#   'spices seasonings',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'canned meals beans',
#   'pasta sauce',
#   'packaged cheese',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'packaged cheese',
#   'oils vinegars'],
#  ['milk', 'milk', 'fresh fruits', 'fresh fruits', 'fresh fruits'],
#  ['specialty wines champagnes',
#   'refrigerated',
#   'bread',
#   'chips pretzels',
#   'milk',
#   'yogurt',
#   'chips pretzels',
#   'fresh fruits',
#   'fresh vegetables',
#   'frozen appetizers sides'],
#  ['milk', 'fresh fruits', 'eggs'],
#  ['fresh vegetables',
#   'packaged vegetables fruits',
#   'yogurt',
#   'condiments',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables'],
#  ['fresh vegetables',
#   'chips pretzels',
#   'chips pretzels',
#   'chips pretzels',
#   'chips pretzels',
#   'chips pretzels',
#   'fresh dips tapenades',
#   'fresh dips tapenades',
#   'popcorn jerky'],
#  ['chips pretzels', 'refrigerated', 'energy granola bars'],
#  ['fresh dips tapenades',
#   'fresh herbs',
#   'fresh fruits',
#   'fresh dips tapenades',
#   'packaged cheese',
#   'packaged cheese'],
#  ['refrigerated',
#   'bread',
#   'ice cream ice',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'water seltzer sparkling water',
#   'canned fruit applesauce',
#   'fresh vegetables',
#   'bulk dried fruits vegetables',
#   'buns rolls',
#   'packaged vegetables fruits',
#   'butter',
#   'laundry',
#   'fresh fruits'],
#  ['packaged produce',
#   'hot cereal pancake mixes',
#   'marinades meat preparation',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'soy lactosefree',
#   'fresh vegetables',
#   'soup broth bouillon',
#   'frozen produce'],
#  ['ice cream ice',
#   'fresh vegetables',
#   'canned jarred vegetables',
#   'paper goods',
#   'fresh vegetables',
#   'paper goods',
#   'hot dogs bacon sausage',
#   'grains rice dried goods',
#   'plates bowls cups flatware',
#   'fresh fruits',
#   'refrigerated',
#   'paper goods',
#   'fresh fruits'],
#  ['fresh fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'yogurt',
#   'butter',
#   'soft drinks',
#   'soft drinks',
#   'milk'],
#  ['baking ingredients',
#   'condiments',
#   'fresh fruits',
#   'milk',
#   'eggs',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'breakfast bars pastries',
#   'packaged meat',
#   'frozen appetizers sides',
#   'dry pasta',
#   'pasta sauce',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'ice cream ice',
#   'bread',
#   'packaged cheese',
#   'soup broth bouillon',
#   'juice nectars',
#   'energy granola bars'],
#  ['fresh fruits',
#   'breakfast bakery',
#   'bread',
#   'cream',
#   'cream',
#   'milk',
#   'spreads',
#   'packaged cheese',
#   'bread',
#   'candy chocolate',
#   'paper goods',
#   'bread'],
#  ['bread',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'hot cereal pancake mixes',
#   'fresh herbs',
#   'fresh vegetables',
#   'refrigerated',
#   'ice cream ice',
#   'yogurt',
#   'soy lactosefree',
#   'packaged vegetables fruits',
#   'fresh vegetables'],
#  ['fresh fruits', 'soy lactosefree'],
#  ['soft drinks',
#   'ice cream ice',
#   'ice cream ice',
#   'ice cream ice',
#   'packaged cheese',
#   'ice cream ice',
#   'ice cream ice',
#   'ice cream ice'],
#  ['baking ingredients',
#   'soft drinks',
#   'fresh fruits',
#   'cleaning products',
#   'refrigerated pudding desserts'],
#  ['packaged produce', 'packaged produce'],
#  ['packaged produce', 'fresh fruits'],
#  ['lunch meat',
#   'refrigerated',
#   'frozen breads doughs',
#   'fresh fruits',
#   'fresh fruits',
#   'breakfast bakery',
#   'cookies cakes',
#   'yogurt',
#   'fresh fruits',
#   'refrigerated',
#   'soft drinks',
#   'soft drinks',
#   'ice cream ice',
#   'butter',
#   'doughs gelatins bake mixes',
#   'packaged poultry',
#   'fresh vegetables'],
#  ['laundry', 'laundry', 'water seltzer sparkling water', 'fresh fruits'],
#  ['water seltzer sparkling water',
#   'candy chocolate',
#   'candy chocolate',
#   'packaged vegetables fruits',
#   'candy chocolate'],
#  ['feminine care',
#   'fresh vegetables',
#   'fresh vegetables',
#   'bread',
#   'fresh vegetables',
#   'fresh vegetables',
#   'lunch meat',
#   'lunch meat'],
#  ['beers coolers', 'yogurt', 'beers coolers'],
#  ['chips pretzels',
#   'fresh fruits',
#   'dry pasta',
#   'fresh vegetables',
#   'packaged vegetables fruits'],
#  ['packaged vegetables fruits', 'soy lactosefree', 'packaged cheese'],
#  ['milk',
#   'fresh fruits',
#   'cream',
#   'fresh fruits',
#   'fresh fruits',
#   'cereal',
#   'bread',
#   'yogurt',
#   'packaged cheese',
#   'fruit vegetable snacks',
#   'cereal',
#   'frozen appetizers sides',
#   'asian foods',
#   'packaged vegetables fruits'],
#  ['candy chocolate',
#   'cookies cakes',
#   'energy granola bars',
#   'candy chocolate',
#   'frozen breakfast',
#   'baking ingredients',
#   'baking ingredients'],
#  ['dog food care',
#   'water seltzer sparkling water',
#   'trash bags liners',
#   'hot dogs bacon sausage',
#   'fresh fruits',
#   'prepared meals',
#   'prepared meals',
#   'milk',
#   'fruit vegetable snacks',
#   'crackers',
#   'chips pretzels',
#   'bread',
#   'ice cream ice',
#   'ice cream ice'],
#  ['packaged vegetables fruits',
#   'pasta sauce',
#   'frozen pizza',
#   'fresh fruits',
#   'food storage',
#   'lunch meat',
#   'latino foods',
#   'dry pasta',
#   'fresh vegetables',
#   'plates bowls cups flatware',
#   'plates bowls cups flatware',
#   'frozen meals',
#   'frozen meals',
#   'frozen meals',
#   'energy granola bars',
#   'packaged poultry',
#   'bread',
#   'chips pretzels',
#   'fresh vegetables',
#   'fresh vegetables'],
#  ['energy granola bars',
#   'fresh fruits',
#   'juice nectars',
#   'water seltzer sparkling water',
#   'water seltzer sparkling water',
#   'packaged vegetables fruits',
#   'fresh dips tapenades'],
#  ['soy lactosefree',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh fruits'],
#  ['red wines',
#   'red wines',
#   'specialty wines champagnes',
#   'red wines',
#   'red wines',
#   'ice cream ice',
#   'ice cream ice',
#   'ice cream ice',
#   'ice cream ice',
#   'ice cream ice',
#   'ice cream ice'],
#  ['fresh fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh fruits',
#   'seafood counter',
#   'poultry counter',
#   'fresh fruits',
#   'fresh herbs',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'dry pasta',
#   'spices seasonings',
#   'fresh vegetables',
#   'soup broth bouillon',
#   'packaged cheese',
#   'pasta sauce',
#   'fresh vegetables',
#   'canned jarred vegetables'],
#  ['baby food formula'],
#  ['packaged vegetables fruits',
#   'fresh vegetables',
#   'packaged cheese',
#   'yogurt',
#   'granola',
#   'tea',
#   'breakfast bakery',
#   'fresh vegetables',
#   'soup broth bouillon',
#   'soup broth bouillon',
#   'prepared soups salads',
#   'soup broth bouillon',
#   'soup broth bouillon',
#   'soup broth bouillon',
#   'soup broth bouillon',
#   'protein meal replacements',
#   'fresh vegetables',
#   'fresh fruits',
#   'soap',
#   'soy lactosefree'],
#  ['fresh vegetables',
#   'packaged poultry',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'fresh vegetables'],
#  ['packaged vegetables fruits',
#   'packaged produce',
#   'packaged produce',
#   'white wines'],
#  ['soy lactosefree',
#   'soy lactosefree',
#   'soy lactosefree',
#   'baking ingredients',
#   'hot cereal pancake mixes',
#   'candy chocolate',
#   'milk',
#   'butter'],
#  ['spices seasonings'],
#  ['water seltzer sparkling water',
#   'nuts seeds dried fruit',
#   'milk',
#   'packaged meat',
#   'fresh herbs',
#   'water seltzer sparkling water',
#   'water seltzer sparkling water',
#   'soy lactosefree',
#   'dry pasta',
#   'fresh fruits',
#   'fresh vegetables',
#   'crackers',
#   'cereal',
#   'dry pasta',
#   'fresh fruits',
#   'soy lactosefree',
#   'fresh vegetables'],
#  ['packaged vegetables fruits',
#   'crackers',
#   'fresh vegetables',
#   'fresh vegetables'],
#  ['milk', 'fresh vegetables', 'condiments', 'other creams cheeses'],
#  ['milk',
#   'cream',
#   'juice nectars',
#   'fresh fruits',
#   'fresh fruits',
#   'yogurt',
#   'packaged cheese',
#   'packaged cheese',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh vegetables',
#   'packaged seafood',
#   'packaged vegetables fruits'],
#  ['frozen meals',
#   'frozen vegan vegetarian',
#   'fresh vegetables',
#   'fresh vegetables',
#   'breakfast bakery',
#   'tofu meat alternatives',
#   'fresh vegetables',
#   'soy lactosefree',
#   'fresh vegetables',
#   'soy lactosefree',
#   'tofu meat alternatives',
#   'grains rice dried goods',
#   'refrigerated',
#   'tea',
#   'chips pretzels',
#   'tofu meat alternatives',
#   'frozen vegan vegetarian',
#   'shave needs',
#   'fresh vegetables',
#   'bread'],
#  ['frozen meals', 'milk'],
#  ['cream',
#   'nuts seeds dried fruit',
#   'yogurt',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'fresh vegetables',
#   'milk',
#   'baby food formula',
#   'poultry counter',
#   'yogurt',
#   'canned meals beans',
#   'baby food formula',
#   'fresh fruits',
#   'cereal',
#   'yogurt'],
#  ['eggs',
#   'fresh vegetables',
#   'tortillas flat bread',
#   'packaged cheese',
#   'hot dogs bacon sausage',
#   'hot dogs bacon sausage',
#   'fresh dips tapenades',
#   'cream',
#   'milk',
#   'lunch meat',
#   'lunch meat',
#   'butter',
#   'bread',
#   'lunch meat',
#   'lunch meat',
#   'refrigerated'],
#  ['buns rolls',
#   'milk',
#   'instant foods',
#   'eggs',
#   'hot dogs bacon sausage',
#   'paper goods',
#   'coffee',
#   'bread',
#   'hot dogs bacon sausage',
#   'packaged vegetables fruits',
#   'grains rice dried goods',
#   'frozen appetizers sides'],
#  ['coffee',
#   'dog food care',
#   'nuts seeds dried fruit',
#   'water seltzer sparkling water',
#   'spices seasonings'],
#  ['fresh vegetables', 'fresh vegetables', 'fresh vegetables'],
#  ['milk',
#   'milk',
#   'yogurt',
#   'eggs',
#   'lunch meat',
#   'chips pretzels',
#   'energy sports drinks',
#   'energy sports drinks',
#   'energy sports drinks',
#   'energy sports drinks',
#   'preserved dips spreads',
#   'crackers',
#   'chips pretzels',
#   'candy chocolate',
#   'nuts seeds dried fruit',
#   'packaged cheese',
#   'bread',
#   'fresh fruits',
#   'frozen pizza',
#   'frozen pizza'],
#  ['fresh fruits'],
#  ['milk',
#   'milk',
#   'soy lactosefree',
#   'cereal',
#   'packaged vegetables fruits',
#   'tofu meat alternatives',
#   'fresh vegetables',
#   'fresh herbs',
#   'fresh herbs',
#   'milk',
#   'other creams cheeses'],
#  ['pasta sauce',
#   'coffee',
#   'baking ingredients',
#   'cream',
#   'butter',
#   'hot cereal pancake mixes',
#   'fresh fruits'],
#  ['condiments',
#   'fresh vegetables',
#   'spices seasonings',
#   'tofu meat alternatives',
#   'fresh vegetables',
#   'asian foods',
#   'fresh vegetables',
#   'baking ingredients',
#   'soft drinks',
#   'milk',
#   'fresh fruits',
#   'other creams cheeses',
#   'canned meals beans',
#   'fresh vegetables',
#   'hot cereal pancake mixes',
#   'fresh fruits'],
#  ['frozen breakfast', 'milk', 'milk', 'water seltzer sparkling water'],
#  ['soup broth bouillon',
#   'fresh fruits',
#   'bakery desserts',
#   'bread',
#   'packaged produce',
#   'fresh vegetables'],
#  ['fresh fruits',
#   'ice cream ice',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'other creams cheeses',
#   'fresh vegetables'],
#  ['water seltzer sparkling water',
#   'soft drinks',
#   'soft drinks',
#   'eggs',
#   'coffee',
#   'spreads',
#   'bread',
#   'poultry counter',
#   'fresh herbs',
#   'fresh vegetables',
#   'cream',
#   'fresh fruits'],
#  ['soy lactosefree',
#   'fresh fruits',
#   'fresh herbs',
#   'packaged vegetables fruits',
#   'nuts seeds dried fruit',
#   'baby food formula',
#   'packaged vegetables fruits',
#   'frozen produce',
#   'fresh vegetables',
#   'baby food formula',
#   'baby food formula',
#   'canned meals beans',
#   'baby food formula'],
#  ['yogurt',
#   'yogurt',
#   'yogurt',
#   'ice cream ice',
#   'packaged poultry',
#   'fresh fruits',
#   'butter',
#   'packaged cheese'],
#  ['energy granola bars',
#   'mint gum',
#   'fruit vegetable snacks',
#   'cookies cakes',
#   'cookies cakes',
#   'fresh fruits'],
#  ['packaged produce',
#   'fresh fruits',
#   'packaged produce',
#   'packaged vegetables fruits',
#   'yogurt',
#   'packaged cheese',
#   'frozen produce'],
#  ['asian foods', 'instant foods', 'instant foods', 'milk', 'instant foods'],
#  ['packaged produce'],
#  ['fresh vegetables',
#   'fresh herbs',
#   'soup broth bouillon',
#   'packaged vegetables fruits',
#   'oils vinegars'],
#  ['energy sports drinks',
#   'frozen meals',
#   'water seltzer sparkling water',
#   'frozen meals',
#   'frozen meals',
#   'energy sports drinks',
#   'cold flu allergy',
#   'laundry'],
#  ['fresh vegetables',
#   'chips pretzels',
#   'canned jarred vegetables',
#   'yogurt',
#   'fresh herbs',
#   'fresh vegetables',
#   'soft drinks',
#   'hot cereal pancake mixes',
#   'tortillas flat bread',
#   'breakfast bakery',
#   'fresh fruits',
#   'soup broth bouillon',
#   'cream'],
#  ['paper goods', 'soft drinks', 'coffee', 'refrigerated', 'buns rolls'],
#  ['fresh vegetables',
#   'yogurt',
#   'ice cream ice',
#   'poultry counter',
#   'specialty cheeses',
#   'fresh vegetables',
#   'packaged cheese',
#   'bread',
#   'pasta sauce',
#   'food storage',
#   'chips pretzels',
#   'fresh fruits',
#   'packaged poultry',
#   'breakfast bakery',
#   'soy lactosefree',
#   'packaged cheese',
#   'chips pretzels',
#   'specialty cheeses',
#   'packaged cheese',
#   'fresh fruits'],
#  ['fresh fruits',
#   'fresh fruits',
#   'popcorn jerky',
#   'canned fruit applesauce',
#   'energy granola bars',
#   'lunch meat',
#   'spreads',
#   'frozen meals',
#   'hot cereal pancake mixes',
#   'cereal',
#   'cereal',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'breakfast bakery'],
#  ['soy lactosefree',
#   'milk',
#   'baking supplies decor',
#   'fresh vegetables',
#   'packaged meat',
#   'pickled goods olives',
#   'packaged cheese',
#   'frozen breakfast',
#   'fresh fruits',
#   'cocoa drink mixes'],
#  ['water seltzer sparkling water',
#   'water seltzer sparkling water',
#   'packaged cheese',
#   'fresh fruits',
#   'meat counter',
#   'chips pretzels',
#   'fresh fruits',
#   'chips pretzels',
#   'nuts seeds dried fruit'],
#  ['milk',
#   'yogurt',
#   'frozen produce',
#   'soy lactosefree',
#   'milk',
#   'fresh fruits',
#   'eggs',
#   'cereal',
#   'baking ingredients',
#   'marinades meat preparation',
#   'frozen breakfast',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'cream',
#   'hot dogs bacon sausage',
#   'ice cream toppings',
#   'packaged vegetables fruits',
#   'canned jarred vegetables',
#   'pasta sauce',
#   'packaged cheese'],
#  ['frozen breakfast',
#   'eggs',
#   'soy lactosefree',
#   'energy granola bars',
#   'fresh fruits',
#   'bread',
#   'butter',
#   'lunch meat',
#   'soy lactosefree',
#   'hot dogs bacon sausage',
#   'energy granola bars',
#   'nuts seeds dried fruit',
#   'canned fruit applesauce',
#   'fresh vegetables',
#   'pickled goods olives',
#   'refrigerated',
#   'chips pretzels',
#   'fresh vegetables',
#   'oral hygiene',
#   'frozen meals'],
#  ['fresh fruits',
#   'fresh fruits',
#   'lunch meat',
#   'hot dogs bacon sausage',
#   'pasta sauce',
#   'canned jarred vegetables',
#   'soup broth bouillon',
#   'fresh fruits',
#   'dry pasta'],
#  ['refrigerated',
#   'water seltzer sparkling water',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'cream',
#   'frozen produce'],
#  ['fresh fruits', 'bread', 'fresh fruits', 'fresh fruits', 'fresh fruits'],
#  ['fresh vegetables',
#   'fresh fruits',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'packaged vegetables fruits',
#   'milk'],
#  ['fresh dips tapenades',
#   'milk',
#   'chips pretzels',
#   'refrigerated',
#   'other creams cheeses',
#   'yogurt',
#   'refrigerated',
#   'refrigerated',
#   'fresh fruits',
#   'eggs',
#   'fresh vegetables',
#   'packaged vegetables fruits'],
#  ['fresh vegetables', 'fresh fruits', 'milk', 'fresh vegetables'],
#  ['plates bowls cups flatware',
#   'cereal',
#   'cereal',
#   'cereal',
#   'cereal',
#   'soy lactosefree',
#   'cereal',
#   'hot cereal pancake mixes',
#   'cereal',
#   'cereal',
#   'cereal',
#   'cereal',
#   'cereal',
#   'soy lactosefree',
#   'muscles joints pain relief',
#   'digestion'],
#  ['soy lactosefree',
#   'ice cream ice',
#   'frozen pizza',
#   'chips pretzels',
#   'refrigerated',
#   'soup broth bouillon',
#   'canned meat seafood',
#   'hot cereal pancake mixes',
#   'breakfast bakery',
#   'other creams cheeses',
#   'crackers',
#   'crackers'],
#  ['granola',
#   'granola',
#   'energy granola bars',
#   'energy granola bars',
#   'energy granola bars',
#   'breakfast bakery',
#   'fresh fruits',
#   'fresh dips tapenades',
#   'tortillas flat bread',
#   'packaged vegetables fruits',
#   'packaged produce',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'butter'],
#  ['milk',
#   'prepared meals',
#   'fresh fruits',
#   'fresh fruits',
#   'frozen produce',
#   'frozen produce',
#   'frozen produce',
#   'packaged vegetables fruits',
#   'baby food formula',
#   'packaged vegetables fruits'],
#  ['coffee',
#   'food storage',
#   'paper goods',
#   'frozen meals',
#   'frozen meals',
#   'eggs',
#   'bread',
#   'soy lactosefree'],
#  ['fresh fruits',
#   'tea',
#   'refrigerated',
#   'yogurt',
#   'yogurt',
#   'yogurt',
#   'refrigerated',
#   'water seltzer sparkling water',
#   'water seltzer sparkling water',
#   'water seltzer sparkling water',
#   'refrigerated',
#   'cream',
#   'energy granola bars',
#   'energy granola bars',
#   'energy granola bars',
#   'energy granola bars',
#   'refrigerated',
#   'chips pretzels',
#   'chips pretzels',
#   'energy granola bars'],
#  ['fresh fruits',
#   'packaged vegetables fruits',
#   'soy lactosefree',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'fresh fruits',
#   'baby food formula',
#   'ice cream ice',
#   'bread',
#   'spreads',
#   'fresh vegetables',
#   'juice nectars',
#   'food storage',
#   'fresh vegetables',
#   'fresh vegetables',
#   'spices seasonings',
#   'fresh vegetables',
#   'dish detergents',
#   'dish detergents'],
#  ['cookies cakes',
#   'pasta sauce',
#   'cleaning products',
#   'candy chocolate',
#   'chips pretzels'],
#  ['protein meal replacements'],
#  ['fresh vegetables',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'instant foods',
#   'chips pretzels',
#   'ice cream ice',
#   'crackers',
#   'fresh vegetables',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'packaged vegetables fruits',
#   'seafood counter',
#   'packaged cheese',
#   'instant foods',
#   'fresh fruits',
#   'fresh fruits',
#   'refrigerated',
#   'cookies cakes',
#   'nuts seeds dried fruit'],
#  ['juice nectars', 'frozen produce'],
#  ['refrigerated',
#   'water seltzer sparkling water',
#   'candy chocolate',
#   'bakery desserts',
#   'ice cream ice',
#   'coffee',
#   'frozen breads doughs',
#   'cream'],
#  ['dish detergents', 'paper goods', 'vitamins supplements'],
#  ['tofu meat alternatives',
#   'chips pretzels',
#   'energy sports drinks',
#   'fresh dips tapenades',
#   'soup broth bouillon',
#   'crackers',
#   'beers coolers',
#   'frozen vegan vegetarian',
#   'bread',
#   'cereal',
#   'soy lactosefree',
#   'canned jarred vegetables',
#   'canned meals beans',
#   'instant foods',
#   'red wines',
#   'fresh fruits',
#   'oils vinegars',
#   'packaged cheese',
#   'fresh vegetables',
#   'fresh vegetables'],
#  ['trail mix snack mix', 'energy sports drinks'],
#  ['spreads',
#   'spreads',
#   'packaged vegetables fruits',
#   'chips pretzels',
#   'fresh fruits',
#   'fresh fruits',
#   'popcorn jerky',
#   'packaged cheese',
#   'frozen produce',
#   'frozen breakfast'],
#  ['soy lactosefree',
#   'canned jarred vegetables',
#   'fresh vegetables',
#   'condiments',
#   'other creams cheeses',
#   'fresh vegetables',
#   'fresh vegetables',
#   'spices seasonings',
#   'fresh herbs',
#   'fresh vegetables'],
#  ['frozen pizza',
#   'grains rice dried goods',
#   'fresh fruits',
#   'bread',
#   'dry pasta',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'frozen meals',
#   'coffee',
#   'fresh vegetables',
#   'pasta sauce',
#   'hair care',
#   'canned meals beans'],
#  ['juice nectars',
#   'fresh vegetables',
#   'milk',
#   'frozen meals',
#   'breakfast bakery',
#   'protein meal replacements',
#   'protein meal replacements',
#   'fresh fruits',
#   'soup broth bouillon',
#   'soup broth bouillon',
#   'soup broth bouillon',
#   'soup broth bouillon',
#   'packaged cheese',
#   'bread',
#   'plates bowls cups flatware',
#   'paper goods',
#   'fresh vegetables',
#   'bakery desserts',
#   'fresh herbs',
#   'frozen meals'],
#  ['frozen breakfast',
#   'fresh fruits',
#   'fresh dips tapenades',
#   'energy granola bars',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'tea',
#   'latino foods',
#   'fresh vegetables',
#   'oils vinegars',
#   'paper goods',
#   'crackers',
#   'fresh vegetables',
#   'fresh vegetables'],
#  ['fresh fruits',
#   'fresh vegetables',
#   'ice cream ice',
#   'doughs gelatins bake mixes',
#   'fresh fruits',
#   'fresh fruits'],
#  ['fresh vegetables', 'yogurt', 'yogurt'],
#  ['meat counter',
#   'fresh vegetables',
#   'other creams cheeses',
#   'cream',
#   'fresh fruits',
#   'packaged cheese',
#   'ice cream ice'],
#  ['bread',
#   'butter',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh fruits',
#   'frozen produce',
#   'ice cream ice',
#   'cookies cakes',
#   'water seltzer sparkling water',
#   'pasta sauce',
#   'dry pasta',
#   'fresh vegetables',
#   'chips pretzels'],
#  ['fresh fruits',
#   'fresh fruits',
#   'milk',
#   'packaged vegetables fruits',
#   'soy lactosefree',
#   'yogurt',
#   'poultry counter',
#   'tortillas flat bread',
#   'fresh vegetables',
#   'eggs',
#   'fresh dips tapenades',
#   'yogurt',
#   'fresh fruits',
#   'other creams cheeses',
#   'bread',
#   'soft drinks',
#   'yogurt',
#   'packaged vegetables fruits'],
#  ['milk',
#   'butter',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'cream',
#   'condiments',
#   'fresh vegetables',
#   'fresh vegetables'],
#  ['frozen meals',
#   'cereal',
#   'fresh fruits',
#   'fresh fruits',
#   'soft drinks',
#   'packaged vegetables fruits',
#   'packaged vegetables fruits',
#   'packaged cheese',
#   'fresh fruits',
#   'milk',
#   'frozen produce',
#   'packaged vegetables fruits',
#   'yogurt',
#   'packaged vegetables fruits',
#   'yogurt',
#   'yogurt',
#   'packaged cheese',
#   'packaged cheese',
#   'yogurt',
#   'packaged cheese'],
#  ['frozen meals',
#   'fresh fruits',
#   'yogurt',
#   'ice cream ice',
#   'ice cream ice',
#   'ice cream ice',
#   'fresh fruits',
#   'frozen appetizers sides',
#   'dry pasta',
#   'refrigerated',
#   'refrigerated'],
#  ['fresh dips tapenades',
#   'spices seasonings',
#   'prepared soups salads',
#   'chips pretzels',
#   'instant foods',
#   'preserved dips spreads',
#   'instant foods',
#   'condiments'],
#  ['paper goods'],
#  ['dry pasta', 'eggs', 'pasta sauce', 'fresh vegetables', 'fresh vegetables'],
#  ['fruit vegetable snacks'],
#  ['breakfast bakery',
#   'frozen breakfast',
#   'cookies cakes',
#   'yogurt',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'yogurt',
#   'fresh fruits',
#   'yogurt'],
#  ['ice cream ice',
#   'ice cream toppings',
#   'frozen vegan vegetarian',
#   'packaged vegetables fruits'],
#  ['food storage',
#   'fresh vegetables',
#   'soup broth bouillon',
#   'fresh vegetables'],
#  ['yogurt',
#   'yogurt',
#   'yogurt',
#   'frozen appetizers sides',
#   'lunch meat',
#   'packaged cheese',
#   'cereal',
#   'eggs',
#   'soy lactosefree',
#   'instant foods',
#   'yogurt',
#   'soy lactosefree',
#   'fresh vegetables',
#   'canned jarred vegetables',
#   'fresh fruits',
#   'soy lactosefree',
#   'butter',
#   'packaged vegetables fruits',
#   'hot dogs bacon sausage',
#   'doughs gelatins bake mixes'],
#  ['fresh fruits',
#   'fresh fruits',
#   'soy lactosefree',
#   'juice nectars',
#   'fresh vegetables',
#   'crackers',
#   'other'],
#  ['poultry counter',
#   'canned jarred vegetables',
#   'paper goods',
#   'tea',
#   'milk',
#   'fresh fruits',
#   'soy lactosefree',
#   'frozen produce'],
#  ['milk'],
#  ['fresh vegetables', 'fresh fruits', 'fresh fruits'],
#  ['deodorants',
#   'deodorants',
#   'pasta sauce',
#   'dry pasta',
#   'vitamins supplements',
#   'energy sports drinks',
#   'energy sports drinks',
#   'ice cream ice',
#   'condiments',
#   'energy sports drinks',
#   'buns rolls',
#   'hot dogs bacon sausage',
#   'canned meals beans',
#   'canned jarred vegetables',
#   'canned meals beans',
#   'canned meals beans',
#   'frozen meals',
#   'feminine care',
#   'feminine care',
#   'instant foods'],
#  ['water seltzer sparkling water',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'crackers',
#   'fresh dips tapenades',
#   'soup broth bouillon',
#   'yogurt',
#   'energy granola bars',
#   'fresh fruits'],
#  ['milk'],
#  ['milk',
#   'cream',
#   'soy lactosefree',
#   'fresh fruits',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'bread',
#   'refrigerated',
#   'fresh fruits',
#   'fresh fruits',
#   'doughs gelatins bake mixes',
#   'hot dogs bacon sausage',
#   'fresh pasta',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula'],
#  ['other',
#   'spreads',
#   'spreads',
#   'other creams cheeses',
#   'eggs',
#   'frozen meat seafood',
#   'marinades meat preparation',
#   'salad dressing toppings',
#   'candy chocolate',
#   'spirits',
#   'refrigerated'],
#  ['mint gum',
#   'eye ear care',
#   'oral hygiene',
#   'cookies cakes',
#   'energy granola bars',
#   'oral hygiene',
#   'body lotions soap',
#   'other'],
#  ['fresh vegetables',
#   'milk',
#   'bread',
#   'packaged poultry',
#   'milk',
#   'lunch meat',
#   'asian foods',
#   'meat counter',
#   'spreads'],
#  ['baby food formula',
#   'milk',
#   'eggs',
#   'packaged cheese',
#   'hot dogs bacon sausage',
#   'juice nectars',
#   'bread',
#   'packaged cheese',
#   'oils vinegars',
#   'packaged cheese',
#   'ice cream ice',
#   'dish detergents',
#   'paper goods',
#   'tortillas flat bread',
#   'yogurt',
#   'eggs',
#   'soft drinks',
#   'frozen breakfast',
#   'packaged vegetables fruits',
#   'bread'],
#  ['fresh vegetables', 'fresh herbs', 'fruit vegetable snacks'],
#  ['ice cream ice',
#   'frozen breakfast',
#   'frozen meat seafood',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula'],
#  ['paper goods',
#   'water seltzer sparkling water',
#   'soft drinks',
#   'popcorn jerky'],
#  ['cream',
#   'fresh fruits',
#   'yogurt',
#   'fresh vegetables',
#   'milk',
#   'fresh vegetables',
#   'juice nectars',
#   'soy lactosefree',
#   'dog food care',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'tea',
#   'tea'],
#  ['frozen appetizers sides'],
#  ['fresh fruits',
#   'asian foods',
#   'milk',
#   'yogurt',
#   'fresh fruits',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'oils vinegars',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh vegetables'],
#  ['fresh fruits',
#   'preserved dips spreads',
#   'fresh fruits',
#   'cat food care',
#   'soy lactosefree',
#   'yogurt',
#   'eggs',
#   'yogurt',
#   'breakfast bakery',
#   'fresh vegetables',
#   'soy lactosefree',
#   'fresh fruits',
#   'soap',
#   'soap',
#   'other creams cheeses'],
#  ['fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'oils vinegars',
#   'soap',
#   'spreads'],
#  ['condiments',
#   'condiments',
#   'popcorn jerky',
#   'juice nectars',
#   'fresh fruits'],
#  ['packaged produce',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'fresh fruits',
#   'packaged produce',
#   'packaged produce',
#   'buns rolls',
#   'buns rolls'],
#  ['fresh fruits',
#   'water seltzer sparkling water',
#   'cream',
#   'bread',
#   'refrigerated',
#   'tea',
#   'fresh vegetables',
#   'poultry counter'],
#  ['frozen produce'],
#  ['eggs',
#   'fresh vegetables',
#   'juice nectars',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'spices seasonings',
#   'fresh vegetables',
#   'fresh fruits',
#   'oils vinegars',
#   'frozen produce',
#   'breakfast bakery',
#   'packaged vegetables fruits',
#   'other creams cheeses',
#   'spices seasonings',
#   'fresh vegetables',
#   'oral hygiene',
#   'bread',
#   'dish detergents',
#   'tortillas flat bread'],
#  ['packaged vegetables fruits'],
#  ['soft drinks', 'fruit vegetable snacks', 'yogurt'],
#  ['fresh fruits',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh fruits',
#   'bread'],
#  ['chips pretzels'],
#  ['fresh fruits',
#   'milk',
#   'fresh vegetables',
#   'soy lactosefree',
#   'fresh fruits',
#   'packaged cheese',
#   'breakfast bakery',
#   'other creams cheeses',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'hot dogs bacon sausage',
#   'fresh dips tapenades',
#   'tortillas flat bread',
#   'yogurt',
#   'other',
#   'canned meals beans',
#   'condiments'],
#  ['soap'],
#  ['baking supplies decor',
#   'canned fruit applesauce',
#   'fresh vegetables',
#   'fresh fruits',
#   'packaged cheese',
#   'soy lactosefree',
#   'fresh vegetables'],
#  ['fresh vegetables',
#   'fresh vegetables',
#   'eggs',
#   'meat counter',
#   'packaged seafood',
#   'refrigerated',
#   'fresh fruits',
#   'fresh herbs',
#   'fresh fruits',
#   'fresh vegetables',
#   'bulk grains rice dried goods',
#   'paper goods'],
#  ['candy chocolate',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'fresh dips tapenades',
#   'packaged vegetables fruits',
#   'crackers',
#   'paper goods',
#   'yogurt',
#   'fresh fruits',
#   'yogurt',
#   'specialty cheeses',
#   'frozen vegan vegetarian',
#   'spreads',
#   'nuts seeds dried fruit'],
#  ['soft drinks',
#   'oils vinegars',
#   'fresh dips tapenades',
#   'tortillas flat bread',
#   'tea',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula'],
#  ['fresh vegetables',
#   'buns rolls',
#   'fresh dips tapenades',
#   'fresh fruits',
#   'milk'],
#  ['soap', 'soy lactosefree', 'fresh fruits'],
#  ['fresh vegetables',
#   'spices seasonings',
#   'refrigerated pudding desserts',
#   'refrigerated',
#   'yogurt',
#   'fresh vegetables',
#   'fresh vegetables',
#   'nuts seeds dried fruit',
#   'packaged cheese',
#   'bread',
#   'milk',
#   'frozen pizza',
#   'fresh vegetables'],
#  ['chips pretzels', 'frozen produce', 'other creams cheeses'],
#  ['yogurt',
#   'fresh fruits',
#   'fresh fruits',
#   'yogurt',
#   'milk',
#   'fresh fruits',
#   'fresh fruits'],
#  ['water seltzer sparkling water',
#   'eggs',
#   'fresh fruits',
#   'fresh vegetables',
#   'oils vinegars',
#   'fresh vegetables',
#   'fresh herbs',
#   'fresh vegetables',
#   'latino foods',
#   'poultry counter'],
#  ['fresh fruits',
#   'candy chocolate',
#   'fresh fruits',
#   'soft drinks',
#   'candy chocolate',
#   'asian foods',
#   'candy chocolate',
#   'packaged cheese',
#   'popcorn jerky',
#   'fruit vegetable snacks',
#   'other',
#   'soy lactosefree'],
#  ['ice cream ice', 'eggs'],
#  ['soup broth bouillon',
#   'soup broth bouillon',
#   'preserved dips spreads',
#   'canned jarred vegetables',
#   'frozen produce',
#   'meat counter',
#   'frozen breakfast',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh herbs',
#   'fresh herbs',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh fruits'],
#  ['fruit vegetable snacks'],
#  ['condiments',
#   'spirits',
#   'packaged vegetables fruits',
#   'milk',
#   'juice nectars',
#   'juice nectars',
#   'juice nectars',
#   'honeys syrups nectars',
#   'soft drinks',
#   'refrigerated'],
#  ['dog food care', 'baby accessories'],
#  ['paper goods',
#   'paper goods',
#   'packaged cheese',
#   'milk',
#   'cat food care',
#   'hair care',
#   'poultry counter',
#   'fresh vegetables',
#   'tortillas flat bread',
#   'fresh vegetables',
#   'marinades meat preparation',
#   'fresh vegetables',
#   'other creams cheeses',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'pasta sauce'],
#  ['milk', 'bread', 'coffee', 'refrigerated'],
#  ['fresh vegetables', 'packaged vegetables fruits', 'canned meals beans'],
#  ['white wines', 'coffee', 'white wines', 'packaged vegetables fruits'],
#  ['asian foods', 'nuts seeds dried fruit', 'baby accessories'],
#  ['fresh fruits',
#   'frozen produce',
#   'refrigerated',
#   'other creams cheeses',
#   'trash bags liners',
#   'baking ingredients',
#   'packaged vegetables fruits',
#   'bread',
#   'butter',
#   'fresh vegetables'],
#  ['fresh fruits',
#   'yogurt',
#   'energy granola bars',
#   'energy granola bars',
#   'yogurt',
#   'fresh vegetables',
#   'fresh vegetables',
#   'spreads',
#   'packaged vegetables fruits',
#   'cream',
#   'crackers',
#   'preserved dips spreads',
#   'poultry counter',
#   'latino foods',
#   'fresh dips tapenades',
#   'milk',
#   'fresh fruits',
#   'fresh fruits'],
#  ['ice cream ice',
#   'fresh vegetables',
#   'fresh vegetables',
#   'soft drinks',
#   'fresh vegetables'],
#  ['ice cream ice',
#   'chips pretzels',
#   'soft drinks',
#   'yogurt',
#   'frozen meals',
#   'dog food care',
#   'packaged cheese',
#   'cookies cakes',
#   'packaged produce',
#   'frozen produce'],
#  ['packaged vegetables fruits',
#   'packaged vegetables fruits',
#   'canned jarred vegetables',
#   'oils vinegars',
#   'fresh herbs',
#   'packaged vegetables fruits',
#   'soup broth bouillon',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh dips tapenades',
#   'fresh dips tapenades'],
#  ['milk', 'water seltzer sparkling water', 'hot dogs bacon sausage', 'eggs'],
#  ['breakfast bakery',
#   'other creams cheeses',
#   'water seltzer sparkling water',
#   'bakery desserts',
#   'fresh vegetables'],
#  ['water seltzer sparkling water',
#   'packaged cheese',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'yogurt',
#   'yogurt',
#   'baking ingredients',
#   'packaged poultry',
#   'crackers',
#   'ice cream ice',
#   'energy granola bars',
#   'frozen produce',
#   'frozen produce',
#   'milk'],
#  ['packaged poultry',
#   'eggs',
#   'ice cream ice',
#   'breakfast bakery',
#   'chips pretzels',
#   'frozen pizza',
#   'hot cereal pancake mixes'],
#  ['cream',
#   'refrigerated',
#   'condiments',
#   'grains rice dried goods',
#   'packaged cheese',
#   'spices seasonings'],
#  ['lunch meat',
#   'fresh fruits',
#   'packaged cheese',
#   'packaged vegetables fruits',
#   'frozen appetizers sides',
#   'butter',
#   'butter',
#   'canned fruit applesauce',
#   'ice cream ice',
#   'fresh fruits',
#   'yogurt'],
#  ['fresh fruits',
#   'water seltzer sparkling water',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'grains rice dried goods',
#   'canned jarred vegetables',
#   'energy granola bars',
#   'energy granola bars',
#   'energy granola bars',
#   'yogurt'],
#  ['packaged vegetables fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'soy lactosefree',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'honeys syrups nectars',
#   'chips pretzels',
#   'frozen meat seafood'],
#  ['oils vinegars',
#   'fresh vegetables',
#   'fresh herbs',
#   'fresh fruits',
#   'soy lactosefree'],
#  ['cereal',
#   'yogurt',
#   'eggs',
#   'deodorants',
#   'energy sports drinks',
#   'refrigerated'],
#  ['fresh fruits',
#   'fresh fruits',
#   'frozen meals',
#   'frozen pizza',
#   'feminine care',
#   'ice cream ice',
#   'refrigerated',
#   'fresh fruits',
#   'yogurt',
#   'yogurt',
#   'yogurt',
#   'soy lactosefree',
#   'nuts seeds dried fruit',
#   'nuts seeds dried fruit',
#   'eggs',
#   'popcorn jerky',
#   'soy lactosefree'],
#  ['fresh fruits',
#   'fresh fruits',
#   'frozen appetizers sides',
#   'milk',
#   'juice nectars',
#   'fresh fruits',
#   'water seltzer sparkling water',
#   'granola',
#   'refrigerated',
#   'frozen breakfast',
#   'eggs',
#   'hot dogs bacon sausage',
#   'bread',
#   'fresh fruits',
#   'canned meals beans',
#   'hot dogs bacon sausage',
#   'coffee',
#   'cookies cakes',
#   'grains rice dried goods',
#   'fresh vegetables'],
#  ['packaged cheese',
#   'eggs',
#   'energy granola bars',
#   'yogurt',
#   'yogurt',
#   'lunch meat',
#   'fresh fruits',
#   'soup broth bouillon',
#   'crackers',
#   'packaged vegetables fruits'],
#  ['fresh fruits',
#   'milk',
#   'refrigerated',
#   'fresh fruits',
#   'packaged cheese',
#   'packaged cheese',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'frozen produce',
#   'other creams cheeses',
#   'pasta sauce',
#   'canned jarred vegetables',
#   'dry pasta',
#   'fresh vegetables',
#   'fresh herbs',
#   'dry pasta',
#   'packaged cheese',
#   'packaged cheese',
#   'pasta sauce',
#   'pasta sauce'],
#  ['eggs',
#   'milk',
#   'milk',
#   'packaged cheese',
#   'packaged vegetables fruits',
#   'bread',
#   'lunch meat',
#   'fresh fruits',
#   'fruit vegetable snacks',
#   'butter',
#   'lunch meat',
#   'packaged vegetables fruits',
#   'packaged cheese',
#   'cream',
#   'spreads',
#   'preserved dips spreads',
#   'grains rice dried goods'],
#  ['energy sports drinks',
#   'soy lactosefree',
#   'chips pretzels',
#   'frozen produce',
#   'packaged cheese'],
#  ['yogurt',
#   'hair care',
#   'hair care',
#   'soy lactosefree',
#   'soy lactosefree',
#   'cereal',
#   'packaged cheese',
#   'packaged vegetables fruits',
#   'packaged cheese',
#   'soup broth bouillon',
#   'frozen vegan vegetarian'],
#  ['diapers wipes'],
#  ['baking ingredients'],
#  ['fresh fruits',
#   'eggs',
#   'frozen breakfast',
#   'milk',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'soup broth bouillon',
#   'fresh fruits',
#   'soy lactosefree',
#   'bread',
#   'fresh vegetables',
#   'soup broth bouillon',
#   'packaged cheese',
#   'poultry counter',
#   'hot cereal pancake mixes'],
#  ['condiments'],
#  ['packaged cheese', 'eggs', 'chips pretzels', 'chips pretzels'],
#  ['canned fruit applesauce',
#   'canned jarred vegetables',
#   'fresh fruits',
#   'packaged produce'],
#  ['milk',
#   'fresh fruits',
#   'frozen meals',
#   'frozen meals',
#   'frozen meals',
#   'frozen meals',
#   'frozen meals'],
#  ['juice nectars', 'frozen pizza', 'baby food formula'],
#  ['water seltzer sparkling water'],
#  ['water seltzer sparkling water',
#   'fresh fruits',
#   'bread',
#   'yogurt',
#   'fresh fruits',
#   'nuts seeds dried fruit',
#   'canned meat seafood',
#   'refrigerated',
#   'soup broth bouillon',
#   'fresh vegetables',
#   'baby food formula',
#   'yogurt',
#   'paper goods',
#   'bread',
#   'fresh fruits',
#   'grains rice dried goods',
#   'soup broth bouillon',
#   'milk',
#   'paper goods',
#   'packaged vegetables fruits'],
#  ['packaged vegetables fruits',
#   'fresh vegetables',
#   'tortillas flat bread',
#   'other creams cheeses',
#   'packaged cheese',
#   'lunch meat'],
#  ['eggs',
#   'other creams cheeses',
#   'frozen produce',
#   'water seltzer sparkling water',
#   'packaged vegetables fruits',
#   'eggs',
#   'fresh fruits',
#   'water seltzer sparkling water'],
#  ['packaged cheese',
#   'fruit vegetable snacks',
#   'milk',
#   'pasta sauce',
#   'fresh herbs',
#   'milk',
#   'water seltzer sparkling water',
#   'butter',
#   'dry pasta',
#   'ice cream ice',
#   'ice cream ice',
#   'bread',
#   'energy sports drinks',
#   'yogurt'],
#  ['butter', 'fresh vegetables', 'other creams cheeses'],
#  ['fresh fruits',
#   'fresh fruits',
#   'yogurt',
#   'yogurt',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'yogurt',
#   'packaged vegetables fruits',
#   'baking ingredients',
#   'yogurt',
#   'nuts seeds dried fruit',
#   'bread',
#   'fresh vegetables',
#   'energy granola bars',
#   'bread',
#   'bread'],
#  ['milk',
#   'water seltzer sparkling water',
#   'eggs',
#   'refrigerated',
#   'packaged vegetables fruits',
#   'frozen breakfast',
#   'lunch meat',
#   'packaged poultry',
#   'other creams cheeses',
#   'fresh fruits',
#   'bread',
#   'yogurt',
#   'frozen breakfast',
#   'hot dogs bacon sausage',
#   'ice cream ice',
#   'ice cream ice',
#   'breakfast bars pastries',
#   'canned meals beans',
#   'pasta sauce',
#   'fresh fruits'],
#  ['baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'condiments',
#   'ice cream ice',
#   'spices seasonings',
#   'spices seasonings',
#   'candy chocolate',
#   'ice cream ice',
#   'pasta sauce'],
#  ['fresh vegetables',
#   'other creams cheeses',
#   'milk',
#   'fresh fruits',
#   'breakfast bakery',
#   'water seltzer sparkling water',
#   'ice cream ice',
#   'chips pretzels',
#   'lunch meat',
#   'energy granola bars',
#   'fresh fruits',
#   'fresh fruits',
#   'yogurt',
#   'asian foods',
#   'packaged vegetables fruits',
#   'fruit vegetable snacks',
#   'fresh fruits',
#   'popcorn jerky',
#   'popcorn jerky',
#   'instant foods'],
#  ['soft drinks',
#   'water seltzer sparkling water',
#   'water seltzer sparkling water',
#   'soft drinks',
#   'cocoa drink mixes',
#   'water seltzer sparkling water',
#   'water seltzer sparkling water',
#   'soft drinks',
#   'soft drinks',
#   'water seltzer sparkling water',
#   'cleaning products',
#   'soft drinks'],
#  ['refrigerated',
#   'packaged poultry',
#   'packaged cheese',
#   'latino foods',
#   'preserved dips spreads',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'milk',
#   'cream',
#   'packaged vegetables fruits',
#   'fresh vegetables'],
#  ['packaged vegetables fruits',
#   'frozen vegan vegetarian',
#   'packaged seafood',
#   'chips pretzels',
#   'energy granola bars',
#   'canned jarred vegetables',
#   'crackers',
#   'fresh fruits',
#   'tofu meat alternatives',
#   'spreads',
#   'asian foods',
#   'asian foods'],
#  ['milk',
#   'frozen appetizers sides',
#   'frozen pizza',
#   'candy chocolate',
#   'candy chocolate',
#   'paper goods'],
#  ['fresh fruits',
#   'frozen breakfast',
#   'frozen meals',
#   'milk',
#   'spreads',
#   'breakfast bakery',
#   'packaged cheese'],
#  ['fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'lunch meat',
#   'fresh fruits'],
#  ['baby food formula',
#   'baby food formula',
#   'diapers wipes',
#   'water seltzer sparkling water',
#   'tofu meat alternatives',
#   'baby food formula',
#   'baby food formula',
#   'coffee',
#   'milk',
#   'crackers',
#   'baby food formula',
#   'chips pretzels'],
#  ['yogurt', 'fresh fruits'],
#  ['butter',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh fruits',
#   'bulk grains rice dried goods',
#   'bulk grains rice dried goods',
#   'dry pasta',
#   'juice nectars',
#   'fresh vegetables',
#   'fresh vegetables',
#   'yogurt',
#   'pasta sauce',
#   'crackers',
#   'crackers',
#   'spreads'],
#  ['first aid',
#   'crackers',
#   'crackers',
#   'milk',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'crackers',
#   'buns rolls',
#   'fruit vegetable snacks',
#   'prepared soups salads',
#   'paper goods',
#   'packaged cheese',
#   'crackers',
#   'fresh vegetables',
#   'fresh vegetables',
#   'breakfast bakery',
#   'prepared meals',
#   'bread',
#   'milk',
#   'juice nectars'],
#  ['chips pretzels',
#   'packaged cheese',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'milk',
#   'soy lactosefree'],
#  ['buns rolls',
#   'fresh fruits',
#   'packaged cheese',
#   'bread',
#   'milk',
#   'packaged produce',
#   'ice cream ice',
#   'ice cream ice',
#   'spices seasonings',
#   'frozen meat seafood'],
#  ['yogurt',
#   'fresh fruits',
#   'fresh fruits',
#   'chips pretzels',
#   'cookies cakes',
#   'fresh dips tapenades',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'water seltzer sparkling water',
#   'packaged vegetables fruits'],
#  ['milk',
#   'fresh vegetables',
#   'fresh fruits',
#   'prepared meals',
#   'condiments',
#   'packaged vegetables fruits',
#   'packaged vegetables fruits'],
#  ['water seltzer sparkling water',
#   'hot cereal pancake mixes',
#   'oils vinegars',
#   'soap',
#   'food storage',
#   'baby food formula',
#   'water seltzer sparkling water',
#   'cold flu allergy',
#   'water seltzer sparkling water'],
#  ['nuts seeds dried fruit', 'cleaning products', 'oils vinegars'],
#  ['cream', 'soy lactosefree', 'fresh dips tapenades', 'butter'],
#  ['paper goods',
#   'mint gum',
#   'candy chocolate',
#   'soup broth bouillon',
#   'deodorants',
#   'refrigerated',
#   'dish detergents',
#   'fresh dips tapenades',
#   'packaged vegetables fruits',
#   'frozen meals',
#   'frozen meals',
#   'frozen meals',
#   'fresh dips tapenades'],
#  ['fresh fruits',
#   'fresh fruits',
#   'bread',
#   'frozen breakfast',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh vegetables',
#   'eggs',
#   'cream',
#   'soy lactosefree',
#   'fresh vegetables',
#   'fresh herbs',
#   'baking ingredients',
#   'fresh vegetables',
#   'soup broth bouillon',
#   'poultry counter',
#   'honeys syrups nectars',
#   'candy chocolate',
#   'hot dogs bacon sausage'],
#  ['cold flu allergy',
#   'yogurt',
#   'cream',
#   'breakfast bakery',
#   'milk',
#   'soup broth bouillon',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'packaged meat',
#   'spices seasonings',
#   'other creams cheeses',
#   'packaged cheese',
#   'fresh vegetables'],
#  ['other creams cheeses',
#   'fresh fruits',
#   'fresh fruits',
#   'ice cream ice',
#   'milk',
#   'energy sports drinks',
#   'indian foods',
#   'frozen breakfast',
#   'fresh vegetables'],
#  ['fresh fruits',
#   'juice nectars',
#   'eggs',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'fresh herbs',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'fresh vegetables'],
#  ['cream'],
#  ['milk', 'popcorn jerky'],
#  ['beers coolers',
#   'chips pretzels',
#   'fresh fruits',
#   'laundry',
#   'milk',
#   'beers coolers'],
#  ['cleaning products',
#   'dish detergents',
#   'canned meals beans',
#   'frozen pizza',
#   'packaged cheese',
#   'fresh vegetables',
#   'specialty cheeses',
#   'juice nectars',
#   'fresh fruits',
#   'juice nectars',
#   'bread',
#   'hair care'],
#  ['frozen meat seafood',
#   'soy lactosefree',
#   'energy granola bars',
#   'frozen breakfast',
#   'first aid',
#   'dish detergents'],
#  ['spices seasonings',
#   'fresh vegetables',
#   'fresh dips tapenades',
#   'fresh vegetables',
#   'soy lactosefree',
#   'milk',
#   'fresh vegetables'],
#  ['baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'baby food formula',
#   'dish detergents',
#   'ice cream ice'],
#  ['packaged vegetables fruits',
#   'fresh vegetables',
#   'yogurt',
#   'water seltzer sparkling water',
#   'fresh fruits',
#   'fresh vegetables',
#   'milk',
# ...
#   'frozen vegan vegetarian'],
#  ['fresh vegetables',
#   'yogurt',
#   'frozen appetizers sides',
#   'frozen produce',
#   'frozen appetizers sides',
#   'frozen appetizers sides',
#   'soy lactosefree',
#   'crackers',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'frozen produce',
#   'vitamins supplements',
#   'cookies cakes',
#   'fresh vegetables',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh vegetables'],
#  ['fresh fruits',
#   'juice nectars',
#   'laundry',
#   'butter',
#   'packaged produce',
#   'lunch meat'],
#  ['fresh vegetables',
#   'fresh fruits',
#   'crackers',
#   'water seltzer sparkling water',
#   'paper goods',
#   'fresh herbs',
#   'eggs',
#   'milk',
#   'condiments',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'fresh vegetables'],
#  ['fresh fruits',
#   'soy lactosefree',
#   'soy lactosefree',
#   'candy chocolate',
#   'cereal',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'cream',
#   'candy chocolate',
#   'chips pretzels',
#   'refrigerated',
#   'packaged poultry',
#   'crackers',
#   'fresh vegetables',
#   'frozen breakfast',
#   'frozen meals',
#   'fresh dips tapenades',
#   'cream',
#   'fresh vegetables',
#   'fresh vegetables'],
#  ['paper goods',
#   'fresh fruits',
#   'milk',
#   'kitchen supplies',
#   'spreads',
#   'crackers',
#   'cookies cakes',
#   'frozen meals'],
#  ['pickled goods olives', 'honeys syrups nectars', 'oils vinegars'],
#  ['spreads',
#   'frozen appetizers sides',
#   'soy lactosefree',
#   'packaged vegetables fruits',
#   'bread',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'packaged meat',
#   'butter',
#   'condiments',
#   'canned meat seafood',
#   'condiments'],
#  ['yogurt',
#   'yogurt',
#   'yogurt',
#   'granola',
#   'yogurt',
#   'plates bowls cups flatware',
#   'plates bowls cups flatware'],
#  ['fresh fruits',
#   'refrigerated',
#   'candy chocolate',
#   'cookies cakes',
#   'yogurt',
#   'soy lactosefree',
#   'breakfast bakery',
#   'bread',
#   'crackers',
#   'packaged cheese',
#   'refrigerated pudding desserts',
#   'crackers',
#   'ice cream ice',
#   'frozen pizza',
#   'cleaning products',
#   'tofu meat alternatives',
#   'baking ingredients',
#   'canned fruit applesauce',
#   'popcorn jerky',
#   'cleaning products'],
#  ['yogurt',
#   'fresh vegetables',
#   'frozen meals',
#   'milk',
#   'fresh fruits',
#   'nuts seeds dried fruit',
#   'frozen vegan vegetarian',
#   'baking ingredients',
#   'packaged cheese',
#   'seafood counter',
#   'packaged vegetables fruits',
#   'yogurt',
#   'fresh vegetables',
#   'canned fruit applesauce',
#   'milk',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'poultry counter'],
#  ['fresh fruits',
#   'cream',
#   'bread',
#   'refrigerated',
#   'coffee',
#   'poultry counter',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'baby bath body care'],
#  ['fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'yogurt',
#   'packaged vegetables fruits',
#   'hot dogs bacon sausage',
#   'lunch meat',
#   'fresh vegetables',
#   'chips pretzels',
#   'soft drinks',
#   'packaged vegetables fruits',
#   'meat counter',
#   'fresh fruits',
#   'packaged poultry',
#   'poultry counter',
#   'fresh dips tapenades',
#   'packaged vegetables fruits',
#   'chips pretzels',
#   'chips pretzels',
#   'milk'],
#  ['packaged vegetables fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'packaged vegetables fruits'],
#  ['lunch meat',
#   'frozen breads doughs',
#   'coffee',
#   'packaged vegetables fruits',
#   'energy granola bars',
#   'energy sports drinks',
#   'fresh fruits'],
#  ['water seltzer sparkling water',
#   'cereal',
#   'cereal',
#   'fresh fruits',
#   'bread',
#   'eggs'],
#  ['milk',
#   'milk',
#   'soup broth bouillon',
#   'yogurt',
#   'granola',
#   'grains rice dried goods',
#   'packaged cheese',
#   'fresh fruits',
#   'crackers'],
#  ['cream', 'dry pasta', 'butter'],
#  ['condiments',
#   'milk',
#   'milk',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh fruits',
#   'canned fruit applesauce',
#   'fresh fruits',
#   'frozen breakfast',
#   'frozen meals',
#   'fresh fruits',
#   'fresh fruits',
#   'packaged cheese',
#   'packaged cheese',
#   'fruit vegetable snacks',
#   'tortillas flat bread',
#   'dry pasta',
#   'pasta sauce',
#   'meat counter',
#   'fresh vegetables'],
#  ['juice nectars', 'soy lactosefree', 'yogurt', 'nuts seeds dried fruit'],
#  ['granola'],
#  ['fresh vegetables',
#   'cream',
#   'milk',
#   'fresh fruits',
#   'yogurt',
#   'fresh fruits',
#   'fresh herbs',
#   'fresh fruits',
#   'packaged cheese'],
#  ['canned meals beans', 'fresh vegetables'],
#  ['packaged produce', 'frozen produce'],
#  ['cleaning products'],
#  ['water seltzer sparkling water',
#   'yogurt',
#   'nuts seeds dried fruit',
#   'tortillas flat bread',
#   'canned meals beans',
#   'pickled goods olives'],
#  ['packaged vegetables fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'soy lactosefree',
#   'fresh vegetables',
#   'milk',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'soap',
#   'cream',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'baby bath body care'],
#  ['meat counter',
#   'cream',
#   'hot dogs bacon sausage',
#   'packaged cheese',
#   'fresh vegetables',
#   'fresh vegetables',
#   'canned jarred vegetables',
#   'packaged cheese'],
#  ['hot dogs bacon sausage',
#   'nuts seeds dried fruit',
#   'granola',
#   'popcorn jerky',
#   'prepared meals',
#   'packaged poultry',
#   'cream',
#   'packaged vegetables fruits',
#   'packaged vegetables fruits',
#   'tea',
#   'ice cream ice',
#   'ice cream ice',
#   'grains rice dried goods',
#   'frozen produce',
#   'frozen produce',
#   'frozen produce',
#   'canned meals beans',
#   'canned jarred vegetables'],
#  ['fresh fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh fruits',
#   'meat counter'],
#  ['fresh fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'frozen appetizers sides',
#   'fresh dips tapenades',
#   'fresh vegetables',
#   'specialty cheeses',
#   'popcorn jerky',
#   'granola',
#   'yogurt',
#   'packaged vegetables fruits'],
#  ['pasta sauce', 'pasta sauce', 'fresh vegetables', 'coffee', 'fresh fruits'],
#  ['candy chocolate',
#   'nuts seeds dried fruit',
#   'refrigerated',
#   'dry pasta',
#   'lunch meat',
#   'pasta sauce',
#   'candy chocolate'],
#  ['fresh fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'energy granola bars',
#   'energy granola bars',
#   'fresh vegetables',
#   'frozen produce',
#   'fresh vegetables',
#   'fresh dips tapenades',
#   'packaged vegetables fruits',
#   'packaged vegetables fruits'],
#  ['soy lactosefree',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'spreads'],
#  ['cream',
#   'laundry',
#   'tortillas flat bread',
#   'energy granola bars',
#   'canned jarred vegetables',
#   'canned meat seafood',
#   'buns rolls',
#   'hot dogs bacon sausage',
#   'fresh vegetables'],
#  ['water seltzer sparkling water',
#   'lunch meat',
#   'crackers',
#   'chips pretzels',
#   'chips pretzels',
#   'soy lactosefree',
#   'soy lactosefree',
#   'prepared soups salads',
#   'crackers',
#   'fresh vegetables',
#   'asian foods',
#   'grains rice dried goods',
#   'soup broth bouillon',
#   'soup broth bouillon',
#   'vitamins supplements'],
#  ['baking ingredients',
#   'hot cereal pancake mixes',
#   'baking ingredients',
#   'bread',
#   'fresh fruits',
#   'eggs',
#   'frozen meals',
#   'cereal',
#   'frozen meals',
#   'instant foods'],
#  ['candy chocolate',
#   'candy chocolate',
#   'candy chocolate',
#   'nuts seeds dried fruit',
#   'trail mix snack mix',
#   'soy lactosefree',
#   'coffee',
#   'nuts seeds dried fruit',
#   'fruit vegetable snacks',
#   'granola',
#   'mint gum',
#   'soy lactosefree',
#   'chips pretzels',
#   'chips pretzels'],
#  ['fresh fruits',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'packaged cheese',
#   'packaged cheese',
#   'frozen produce',
#   'fresh vegetables'],
#  ['frozen meat seafood',
#   'packaged cheese',
#   'other creams cheeses',
#   'trail mix snack mix'],
#  ['milk',
#   'fresh fruits',
#   'fresh vegetables',
#   'baking ingredients',
#   'cream',
#   'dish detergents',
#   'other creams cheeses',
#   'other creams cheeses',
#   'fresh vegetables',
#   'soy lactosefree',
#   'oils vinegars',
#   'packaged cheese',
#   'crackers',
#   'crackers'],
#  ['yogurt',
#   'ice cream ice',
#   'yogurt',
#   'packaged cheese',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh dips tapenades'],
#  ['eggs',
#   'fresh fruits',
#   'energy granola bars',
#   'breakfast bakery',
#   'yogurt',
#   'chips pretzels',
#   'packaged cheese',
#   'yogurt',
#   'yogurt',
#   'yogurt',
#   'juice nectars',
#   'fresh fruits'],
#  ['nuts seeds dried fruit',
#   'doughs gelatins bake mixes',
#   'doughs gelatins bake mixes',
#   'oils vinegars',
#   'baby food formula'],
#  ['juice nectars',
#   'water seltzer sparkling water',
#   'fresh fruits',
#   'frozen breakfast',
#   'bread',
#   'water seltzer sparkling water',
#   'grains rice dried goods',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'lunch meat',
#   'frozen appetizers sides',
#   'crackers',
#   'fresh fruits'],
#  ['fresh fruits', 'bread', 'water seltzer sparkling water'],
#  ['specialty wines champagnes',
#   'white wines',
#   'packaged vegetables fruits',
#   'spirits',
#   'water seltzer sparkling water',
#   'chips pretzels',
#   'popcorn jerky',
#   'oral hygiene',
#   'body lotions soap'],
#  ['energy sports drinks',
#   'energy sports drinks',
#   'fresh fruits',
#   'canned fruit applesauce',
#   'bread',
#   'bread'],
#  ['soup broth bouillon',
#   'soup broth bouillon',
#   'soup broth bouillon',
#   'skin care',
#   'water seltzer sparkling water',
#   'canned jarred vegetables',
#   'packaged meat'],
#  ['hot dogs bacon sausage',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'baby food formula',
#   'frozen meals',
#   'soy lactosefree',
#   'fresh fruits',
#   'bread',
#   'yogurt',
#   'doughs gelatins bake mixes',
#   'packaged vegetables fruits',
#   'hot dogs bacon sausage',
#   'packaged cheese',
#   'baby bath body care',
#   'fresh fruits',
#   'hot dogs bacon sausage',
#   'milk',
#   'breakfast bars pastries',
#   'baby food formula',
#   'fresh pasta'],
#  ['fresh fruits',
#   'fresh herbs',
#   'fresh fruits',
#   'canned jarred vegetables',
#   'canned jarred vegetables',
#   'packaged cheese',
#   'packaged vegetables fruits',
#   'refrigerated',
#   'refrigerated',
#   'grains rice dried goods',
#   'packaged cheese',
#   'fresh vegetables',
#   'baking ingredients',
#   'fresh fruits'],
#  ['frozen produce',
#   'frozen produce',
#   'fresh fruits',
#   'yogurt',
#   'spices seasonings',
#   'breakfast bakery',
#   'frozen produce',
#   'refrigerated'],
#  ['baby food formula',
#   'energy granola bars',
#   'protein meal replacements',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'packaged cheese',
#   'juice nectars',
#   'refrigerated',
#   'lunch meat',
#   'frozen appetizers sides',
#   'canned meals beans',
#   'soup broth bouillon',
#   'frozen meals',
#   'frozen meals',
#   'fresh fruits'],
#  ['canned meat seafood',
#   'oils vinegars',
#   'feminine care',
#   'fresh vegetables',
#   'poultry counter',
#   'fresh herbs',
#   'chips pretzels',
#   'fresh vegetables',
#   'candy chocolate'],
#  ['packaged vegetables fruits',
#   'butter',
#   'packaged cheese',
#   'frozen produce',
#   'frozen produce',
#   'frozen produce',
#   'fresh dips tapenades',
#   'milk',
#   'packaged cheese'],
#  ['fresh fruits',
#   'water seltzer sparkling water',
#   'spices seasonings',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh vegetables',
#   'canned jarred vegetables',
#   'nuts seeds dried fruit',
#   'soap',
#   'condiments',
#   'fresh vegetables',
#   'refrigerated',
#   'refrigerated',
#   'refrigerated',
#   'grains rice dried goods',
#   'condiments',
#   'instant foods',
#   'fresh fruits',
#   'fresh herbs',
#   'packaged vegetables fruits'],
#  ['chips pretzels',
#   'chips pretzels',
#   'chips pretzels',
#   'chips pretzels',
#   'chips pretzels'],
#  ['soy lactosefree',
#   'ice cream ice',
#   'yogurt',
#   'packaged vegetables fruits',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'fresh vegetables'],
#  ['soy lactosefree', 'frozen breakfast', 'cream'],
#  ['bread', 'lunch meat', 'packaged cheese'],
#  ['soup broth bouillon', 'chips pretzels', 'popcorn jerky'],
#  ['cold flu allergy',
#   'vitamins supplements',
#   'cold flu allergy',
#   'bread',
#   'frozen meals',
#   'soy lactosefree',
#   'frozen meals',
#   'baking ingredients'],
#  ['soft drinks',
#   'energy sports drinks',
#   'instant foods',
#   'specialty cheeses',
#   'energy sports drinks'],
#  ['frozen produce',
#   'frozen produce',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh fruits',
#   'milk',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'chips pretzels',
#   'fresh vegetables',
#   'frozen produce',
#   'yogurt',
#   'canned meals beans',
#   'pasta sauce',
#   'paper goods',
#   'packaged cheese',
#   'fresh vegetables',
#   'oils vinegars'],
#  ['fresh fruits', 'latino foods'],
#  ['oils vinegars',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'eggs',
#   'fresh vegetables',
#   'fresh dips tapenades',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh vegetables',
#   'canned jarred vegetables',
#   'frozen appetizers sides',
#   'protein meal replacements',
#   'fresh fruits',
#   'fresh fruits',
#   'other creams cheeses',
#   'dry pasta',
#   'pasta sauce'],
#  ['fresh vegetables', 'butter', 'nuts seeds dried fruit', 'yogurt', 'yogurt'],
#  ['fresh fruits',
#   'oils vinegars',
#   'pasta sauce',
#   'packaged produce',
#   'fresh vegetables',
#   'packaged produce',
#   'fresh fruits',
#   'packaged produce',
#   'eggs'],
#  ['soy lactosefree',
#   'soy lactosefree',
#   'fresh fruits',
#   'ice cream ice',
#   'cereal',
#   'water seltzer sparkling water'],
#  ['dish detergents',
#   'refrigerated',
#   'water seltzer sparkling water',
#   'tea',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh fruits',
#   'lunch meat',
#   'fresh fruits',
#   'soy lactosefree',
#   'fresh vegetables'],
#  ['fresh vegetables',
#   'yogurt',
#   'fresh fruits',
#   'milk',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'soy lactosefree',
#   'soy lactosefree',
#   'soy lactosefree',
#   'fresh vegetables',
#   'fresh fruits',
#   'soy lactosefree',
#   'fresh fruits',
#   'canned jarred vegetables',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'yogurt',
#   'yogurt'],
#  ['fresh fruits',
#   'fresh dips tapenades',
#   'fresh herbs',
#   'fresh herbs',
#   'other creams cheeses',
#   'bread',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh vegetables'],
#  ['nuts seeds dried fruit',
#   'nuts seeds dried fruit',
#   'nuts seeds dried fruit',
#   'nuts seeds dried fruit',
#   'soft drinks',
#   'soft drinks',
#   'asian foods'],
#  ['refrigerated',
#   'water seltzer sparkling water',
#   'vitamins supplements',
#   'other creams cheeses',
#   'packaged cheese',
#   'packaged cheese'],
#  ['fresh fruits',
#   'milk',
#   'packaged vegetables fruits',
#   'popcorn jerky',
#   'eggs',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'spices seasonings',
#   'latino foods',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'fresh fruits',
#   'fresh vegetables',
#   'fresh vegetables',
#   'nuts seeds dried fruit'],
#  ['yogurt', 'fresh vegetables', 'canned jarred vegetables', 'yogurt'],
#  ['ice cream ice',
#   'fresh vegetables',
#   'cereal',
#   'fresh vegetables',
#   'fresh fruits',
#   'fresh fruits',
#   'bread',
#   'milk',
#   'yogurt',
#   'fresh vegetables',
#   'yogurt',
#   'buns rolls',
#   'fresh vegetables',
#   'yogurt',
#   'crackers',
#   'chips pretzels',
#   'fresh fruits',
#   'lunch meat',
#   'baby food formula',
#   'packaged cheese'],
#  ['paper goods', 'laundry', 'body lotions soap', 'baby food formula', 'milk'],
#  ['fresh fruits',
#   'packaged vegetables fruits',
#   'soy lactosefree',
#   'eggs',
#   'fresh fruits',
#   'packaged vegetables fruits',
#   'yogurt',
#   'packaged vegetables fruits',
#   'fresh fruits',
#   'popcorn jerky',
#   'fresh vegetables',
#   'packaged cheese',
#   'fresh fruits',
#   'paper goods',
#   'oils vinegars',
#   'packaged cheese',
#   'fresh vegetables',
#   'fresh vegetables',
#   'fresh vegetables',
#   'instant foods'],
#  ['coffee',
#   'canned meals beans',
#   'canned meals beans',
#   'packaged vegetables fruits',
#   'yogurt',
#   'yogurt',
#   'nuts seeds dried fruit'],
#  ...]

# %% [markdown]
# ## Parâmetros do apriori
# * **transactions:** lista com listas de items. Ex: [[banana, maçã, peixe], [maça, arroz, frutas], [arroz, banana, leite]
#
# * **min_support:** percentual minimo que produto aparece nas transações (0.01 = 1%)
#
# * **min_confidence:** percentual mínimo que outro produto comprado com o produto principal aparece nas mesmas transações (0.1 = 10%)
#
# * **min_lift:** Usado para medir o quão mais provável é a ocorrência conjunta do produto A com produto B. Maior que 1 indica uma associação positiva, enquanto um lift menor que 1 indica uma associação negativa.
#
# * **min_length:** minimo de combinação de produtos (se for 1 o produto será comparado a ele mesmo)
#
# * **max_length:** máximo de combinação de produtos

# %%
# execução do apriori para descobrir combinações
resultado = list(apriori(
    transactions = transactions,
    min_support = 0.01, # percentual minimo que produto aparece nas transações (0.01 = 1%)
    min_confidence = 0.1, # percentual mínimo que outro produto comprado com o produto principal aparece nas mesmas transações (0.1 = 10%)
    min_lift = 1.2, # Usado para medir o quão mais provável é a ocorrência conjunta do produto A com produto B.
                    # Maior que 1 indica uma associação positiva, enquanto um lift menor que 1 indica uma associação negativa.
    min_length = 2, # minimo de combinação de produtos (se for 1 o produto será comparado a ele mesmo)
    max_length = 3 # máximo de combinação de produtos
    ))

# %%
#importa o resultado do apriori para um dataframe
resultado_df = pd.DataFrame()

for x in range (len(resultado)):
    nova_linha = {
        'Items Base' : ', '.join(list(resultado[x][2][0][0])),
        'Items Adicional' : ', '.join(list(resultado[x][2][0][1])),
        'Suporte' : resultado[x][1],
        'Confiança': resultado[x][2][0][2],
        'Lift' : resultado[x][2][0][3]
    }

    resultado_df = pd.concat([resultado_df, pd.DataFrame([nova_linha])], ignore_index=True)

#exibe o dataframe ordenando os maiores lifts
resultado_df.sort_values(by=['Lift'], ascending=False)
# Out:
#                    Items Base                        Items Adicional  \
# 694                 dry pasta              pasta sauce, fresh fruits
# 172                 dry pasta                            pasta sauce
# 698                 dry pasta          fresh vegetables, pasta sauce
# 528  canned jarred vegetables  fresh vegetables, soup broth bouillon
# 940               fresh herbs        fresh vegetables, oils vinegars
# ..                        ...                                    ...
# 31                      bread                         frozen produce
# 506  butter, fresh vegetables                                 yogurt
# 151                  crackers             packaged vegetables fruits
# 177                      eggs                           fresh fruits
# 381           soy lactosefree                                 yogurt
#
#       Suporte  Confiança      Lift
# 694  0.011982   0.208696  5.291359
# 172  0.017474   0.304348  5.210331
# 698  0.010484   0.182609  5.151623
# 528  0.013480   0.198529  4.230366
# 940  0.011483   0.140244  4.131008
# ..        ...        ...       ...
# 31   0.020969   0.132075  1.202487
# 506  0.011483   0.310811  1.201842
# 151  0.042936   0.403756  1.201669
# 177  0.089366   0.660517  1.201648
# 381  0.051922   0.310448  1.200438
#
# [1091 rows x 5 columns]

# %% [markdown]
# ## Conclusão
# Na coluna Lift representa a probalidade maior de itens associados saírem juntos do que separado. Ex: *{dry pasta, pasta sauce, fresh fruits}* tem **5 vezes** mais chances de saírem juntos, do que se estiverem vendidos separadamente.
